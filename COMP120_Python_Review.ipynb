# %% [markdown]
# <a href="https://colab.research.google.com/github/usd-comp120/python-review/blob/main/COMP120_Python_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem: Grade File Individualizer
#
# Assume you have a file with grade informationn for all students, in the following format.
#
# ```
# Student,Grade,Comments
# Aaron,8.5,Missing type hints
# Tori,6,foo function missing,bar fails some tests
# Greg,10,Amazing work
# Mohammed,9,Print formatting is incorrect
# ```
#
# We would like to write a function that reads this file and creates individual feedback files for each of the students. For example, it would create a file named Aaron.txt with the following format.
#
# ```
# Grade: 8.5
# Comments:
# 1. Missing type hints
# ```
#
# Similarly, it would create a file named Tori.txt with the following format.
#
# ```
# Grade: 6.0
# Comments:
# 1. foo function missing
# 2. bar fails some tests
# ```

# %%
# Run this cell to download the example CSV file (psa_grades.csv)
# !wget https://raw.githubusercontent.com/usd-comp120/python-review/refs/heads/main/psa_grades.csv
# Out:
# --2026-01-29 16:59:10--  https://raw.githubusercontent.com/usd-comp120/python-review/refs/heads/main/psa_grades.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163 [text/plain]
# Saving to: ‘psa_grades.csv.1’
#
# psa_grades.csv.1    100%[===================>]     163  --.-KB/s    in 0s
#
# 2026-01-29 16:59:10 (7.02 MB/s) - ‘psa_grades.csv.1’ saved [163/163]

# %% [markdown]
# Check that the file was successfully downloaded by opening up the "files" menu (to the left) and verify there is a file named `psa_grades.csv` listed there.
#
# Clicking on the file should reveal the same contents as the example shown above. If not, get the instructor's attention.

# %%
def individualize_grades(filename):
  """ To Do: Complete this docstring comment. """

  pass # implement this function and remove this pass statement

# %% [markdown]
# Now let's test things out by running your function on the `psa_grades.csv` file that you downloaded earlier.

# %%
# add a line of code here to call your function

# %% [markdown]
# To test the correctness of your function, you'll need to example the output of the files created by this function (e.g. Aaron.txt).
#
# To do so, open up the "Files" menu and confirm that you have the expected number of files and that their contents are *exactly* as expected.
